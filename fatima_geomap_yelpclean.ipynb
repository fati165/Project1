# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# Study data files
yelp_path = "data/Final_Yelp_Data.csv"

# Read the mouse data and the study results
yelpers = pd.read_csv(yelp_path)

# %%
yelpers.head()
# Out:
#    Unnamed: 0                      id                                 alias  \
# 0           0  Y3HNUBQJHAzWnnhk3iReiA  junoon-flavors-of-india-sacramento-2
# 1           1  9GhIDT1D_8-0ZxKDIB2WpA                shake-shack-sacramento
# 2           2  LwiOfwMNDndIPm3QSh8wFQ                      south-sacramento
# 3           3  myoaFyZ9RIG_p2rkOQiWlA      fixins-soul-kitchen-sacramento-2
# 4           4  rQaH3Jr6BxFhX5pXa6W6_w             chando-s-tacos-sacramento
#
#                       name                                          image_url  \
# 0  Junoon Flavors Of India  https://s3-media1.fl.yelpcdn.com/bphoto/P7Pzdg...
# 1              Shake Shack  https://s3-media3.fl.yelpcdn.com/bphoto/TxbovZ...
# 2                    South  https://s3-media3.fl.yelpcdn.com/bphoto/yHsuXv...
# 3      Fixins Soul Kitchen  https://s3-media4.fl.yelpcdn.com/bphoto/wVYnJG...
# 4           Chando’s Tacos  https://s3-media2.fl.yelpcdn.com/bphoto/yoraiB...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/junoon-flavors-of-ind...            20
# 1      False  https://www.yelp.com/biz/shake-shack-sacrament...           168
# 2      False  https://www.yelp.com/biz/south-sacramento?adju...          1590
# 3      False  https://www.yelp.com/biz/fixins-soul-kitchen-s...           946
# 4      False  https://www.yelp.com/biz/chando-s-tacos-sacram...            14
#
#                                           categories  rating  \
# 0           [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2       [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
#
#                                          coordinates  transactions  \
# 0  {'latitude': 38.570471, 'longitude': -121.4571...            []
# 1  {'latitude': 38.568686, 'longitude': -121.487243}  ['delivery']
# 2  {'latitude': 38.5687015705627, 'longitude': -1...  ['delivery']
# 3    {'latitude': 38.55147, 'longitude': -121.46924}  ['delivery']
# 4  {'latitude': 38.564075, 'longitude': -121.4340...            []
#
#                                             location         phone  \
# 0  {'address1': '3672 J St', 'address2': None, 'a...  1.916943e+10
# 1  {'address1': '1710 R St', 'address2': 'Ste 190...  1.279321e+10
# 2  {'address1': '2005 11th St', 'address2': '', '...  1.916383e+10
# 3  {'address1': '3428 3rd Ave', 'address2': '', '...  1.917000e+10
# 4  {'address1': '5644 J St', 'address2': '', 'add...  1.916477e+10
#
#     display_phone     distance price  Unnamed: 0.1
# 0  (916) 942-9796  1267.138005   NaN           NaN
# 1  (279) 321-4002  3883.061550   NaN           NaN
# 2  (916) 382-9722  4735.638709    $$           NaN
# 3  (916) 999-7685  3270.943674    $$           NaN
# 4  (916) 476-6312  1210.413973   NaN           NaN

# %%
#compare each type of food and review count
df = pd.DataFrame(yelpers, columns = ['name', 'categories', 'review_count', 'rating', 'transactions', 'coordinates']) 

df.head()
# Out:
#                       name                                         categories  \
# 0  Junoon Flavors Of India           [{'alias': 'indpak', 'title': 'Indian'}]
# 1              Shake Shack  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 2                    South       [{'alias': 'southern', 'title': 'Southern'}]
# 3      Fixins Soul Kitchen  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...
# 4           Chando’s Tacos         [{'alias': 'mexican', 'title': 'Mexican'}]
#
#    review_count  rating  transactions  \
# 0            20     5.0            []
# 1           168     3.0  ['delivery']
# 2          1590     4.0  ['delivery']
# 3           946     4.5  ['delivery']
# 4            14     4.5            []
#
#                                          coordinates
# 0  {'latitude': 38.570471, 'longitude': -121.4571...
# 1  {'latitude': 38.568686, 'longitude': -121.487243}
# 2  {'latitude': 38.5687015705627, 'longitude': -1...
# 3    {'latitude': 38.55147, 'longitude': -121.46924}
# 4  {'latitude': 38.564075, 'longitude': -121.4340...

# %%
#geomap the restaurants with most reviews

df['lat'], df['long'] = df['coordinates'].str.split(',', 1).str
df['lat']= df['lat'].str.replace("{'latitude':", "")
df['long'] = df['long'].str.replace("'longitude': ", "").str.replace("}", "")
df[['long', 'lat']]= df[['long', 'lat']].astype(float, errors= "ignore")
df
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                             name  \
# 20            Ramen House Ryujin
# 15                 Oz Korean BBQ
# 48             Iron Horse Tavern
# 40                 Tres Hermanas
# 350                   Yard House
# ..                           ...
# 262              Sun Center Cafe
# 468  Bacchanal Bistro & Wine Bar
# 175             Leonardi's Pizza
# 162     Hall of Fame Bar & Grill
# 494                   Young Dong
#
#                                             categories  review_count  rating  \
# 20   [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...          2881     4.5
# 15   [{'alias': 'korean', 'title': 'Korean'}, {'ali...          2647     4.0
# 48   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...          2435     4.0
# 40          [{'alias': 'mexican', 'title': 'Mexican'}]          2397     4.0
# 350  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...          2071     3.5
# ..                                                 ...           ...     ...
# 262             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 468             [{'alias': 'pizza', 'title': 'Pizza'}]             1     5.0
# 175             [{'alias': 'pizza', 'title': 'Pizza'}]             1     5.0
# 162  [{'alias': 'newamerican', 'title': 'American (...             1     3.0
# 494           [{'alias': 'korean', 'title': 'Korean'}]             1     1.0
#
#     transactions                                        coordinates  \
# 20          True      {'latitude': 38.5674, 'longitude': -121.4857}
# 15          True    {'latitude': 38.56349, 'longitude': -121.33496}
# 48          True  {'latitude': 38.5695762064691, 'longitude': -1...
# 40          True    {'latitude': 38.57369, 'longitude': -121.47456}
# 350         True  {'latitude': 38.768878772817, 'longitude': -12...
# ..           ...                                                ...
# 262        False  {'latitude': 38.554607, 'longitude': -121.373375}
# 468        False    {'latitude': 38.74375, 'longitude': -121.25349}
# 175        False  {'latitude': 38.741153717041, 'longitude': -12...
# 162         True  {'latitude': 38.7098999, 'longitude': -121.291...
# 494         True  {'latitude': 38.52425, 'longitude': -121.4971651}
#
#                    lat                long
# 20             38.5674           -121.4857
# 15            38.56349          -121.33496
# 48    38.5695762064691   -121.490668354958
# 40            38.57369          -121.47456
# 350    38.768878772817    -121.26806509957
# ..                 ...                 ...
# 262          38.554607         -121.373375
# 468           38.74375          -121.25349
# 175    38.741153717041    -121.24925994873
# 162         38.7098999        -121.2913132
# 494           38.52425        -121.4971651
#
# [613 rows x 8 columns]

# %%
df= df.sort_values("review_count", ascending= False)
top20= df.head(20)
top20[['long', 'lat']]= top20[['long', 'lat']].astype(float)
top20
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                           name  \
# 20          Ramen House Ryujin
# 15               Oz Korean BBQ
# 48           Iron Horse Tavern
# 40               Tres Hermanas
# 350                 Yard House
# 23       Sawasdee Thai Cuisine
# 135   Ella Dining Room and Bar
# 352          Four Sisters Cafe
# 120                Fox & Goose
# 36       Public House Downtown
# 37            The Coconut On T
# 2                        South
# 31                    Paesanos
# 343  Lazy Dog Restaurant & Bar
# 33    The Firehouse Restaurant
# 341            My Thai Kitchen
# 373                    Topgolf
# 354                     Zócalo
# 340           The Chef's Table
# 265  Evan's Kitchen & Catering
#
#                                             categories  review_count  rating  \
# 20   [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...          2881     4.5
# 15   [{'alias': 'korean', 'title': 'Korean'}, {'ali...          2647     4.0
# 48   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...          2435     4.0
# 40          [{'alias': 'mexican', 'title': 'Mexican'}]          2397     4.0
# 350  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...          2071     3.5
# 23                [{'alias': 'thai', 'title': 'Thai'}]          2021     4.5
# 135  [{'alias': 'newamerican', 'title': 'American (...          1756     4.0
# 352  [{'alias': 'breakfast_brunch', 'title': 'Break...          1749     4.5
# 120  [{'alias': 'breakfast_brunch', 'title': 'Break...          1729     3.5
# 36   [{'alias': 'newamerican', 'title': 'American (...          1705     4.0
# 37   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...          1618     4.5
# 2         [{'alias': 'southern', 'title': 'Southern'}]          1590     4.0
# 31   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...          1550     4.0
# 343  [{'alias': 'newamerican', 'title': 'American (...          1485     4.0
# 33   [{'alias': 'newamerican', 'title': 'American (...          1422     4.0
# 341               [{'alias': 'thai', 'title': 'Thai'}]          1389     4.0
# 373  [{'alias': 'newamerican', 'title': 'American (...          1350     4.0
# 354         [{'alias': 'mexican', 'title': 'Mexican'}]          1315     4.0
# 340  [{'alias': 'newamerican', 'title': 'American (...          1271     4.5
# 265  [{'alias': 'tradamerican', 'title': 'American ...          1186     4.0
#
#     transactions                                        coordinates  \
# 20          True      {'latitude': 38.5674, 'longitude': -121.4857}
# 15          True    {'latitude': 38.56349, 'longitude': -121.33496}
# 48          True  {'latitude': 38.5695762064691, 'longitude': -1...
# 40          True    {'latitude': 38.57369, 'longitude': -121.47456}
# 350         True  {'latitude': 38.768878772817, 'longitude': -12...
# 23          True  {'latitude': 38.576894, 'longitude': -121.481515}
# 135         True     {'latitude': 38.57887, 'longitude': -121.4914}
# 352         True  {'latitude': 38.784513, 'longitude': -121.266579}
# 120         True  {'latitude': 38.5715283845259, 'longitude': -1...
# 36          True  {'latitude': 38.576166714481, 'longitude': -12...
# 37          True     {'latitude': 38.5685, 'longitude': -121.49658}
# 2           True  {'latitude': 38.5687015705627, 'longitude': -1...
# 31          True  {'latitude': 38.573753, 'longitude': -121.483764}
# 343         True  {'latitude': 38.7750242, 'longitude': -121.275...
# 33          True  {'latitude': 38.581539, 'longitude': -121.504931}
# 341         True  {'latitude': 38.7530926018765, 'longitude': -1...
# 373        False   {'latitude': 38.79075, 'longitude': -121.295726}
# 354         True  {'latitude': 38.76814736, 'longitude': -121.26...
# 340         True  {'latitude': 38.7964080881302, 'longitude': -1...
# 265         True  {'latitude': 38.5660479112045, 'longitude': -1...
#
#            lat        long
# 20   38.567400 -121.485700
# 15   38.563490 -121.334960
# 48   38.569576 -121.490668
# 40   38.573690 -121.474560
# 350  38.768879 -121.268065
# 23   38.576894 -121.481515
# 135  38.578870 -121.491400
# 352  38.784513 -121.266579
# 120  38.571528 -121.496973
# 36   38.576167 -121.486356
# 37   38.568500 -121.496580
# 2    38.568702 -121.497105
# 31   38.573753 -121.483764
# 343  38.775024 -121.275245
# 33   38.581539 -121.504931
# 341  38.753093 -121.251940
# 373  38.790750 -121.295726
# 354  38.768147 -121.269764
# 340  38.796408 -121.290667
# 265  38.566048 -121.432720

# %%
df= df.sort_values("review_count", ascending= False)
tail= df[df["review_count"]==1]
tail[['long', 'lat']]= tail[['long', 'lat']].astype(float)
tail
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                   name  \
# 507  Virga's Restaurant Bar & Catering
# 65                   Outdoor Herbivore
# 506                 Mango’s Burger Bar
# 482         Las Cachanillas Restaurant
# 451                        Burger King
# 246               Larosa's Sports Cafe
# 460                            Cafe 26
# 480                         Café Hoshi
# 267                 Fair Oaks Pizzeria
# 252                    Classic Burgers
# 405                      Culinary Café
# 50              Playa Linda Del Carmen
# 238                        3- N -1 BBQ
# 535                     La Boheme Cafe
# 313        Five-Twenty Four Restaurant
# 146                      Baker Dozen 2
# 162           Hall of Fame Bar & Grill
# 175                   Leonardi's Pizza
# 468        Bacchanal Bistro & Wine Bar
# 284                   Chili's Catering
# 262                    Sun Center Cafe
# 411        Riego Road Strawberry Stand
# 213                      El Zacatecano
# 205             La Croissant Park Cafe
# 305                          TACOS GTO
# 494                         Young Dong
#
#                                             categories  review_count  rating  \
# 507  [{'alias': 'restaurants', 'title': 'Restaurant...             1     4.0
# 65   [{'alias': 'diyfood', 'title': 'Do-It-Yourself...             1     5.0
# 506  [{'alias': 'salad', 'title': 'Salad'}, {'alias...             1     4.0
# 482  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...             1     4.0
# 451  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...             1     4.0
# 246  [{'alias': 'restaurants', 'title': 'Restaurant...             1     1.0
# 460  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...             1     4.0
# 480             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 267  [{'alias': 'restaurants', 'title': 'Restaurant...             1     1.0
# 252  [{'alias': 'restaurants', 'title': 'Restaurant...             1     1.0
# 405             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 50     [{'alias': 'latin', 'title': 'Latin American'}]             1     5.0
# 238            [{'alias': 'bbq', 'title': 'Barbeque'}]             1     5.0
# 535  [{'alias': 'restaurants', 'title': 'Restaurant...             1     4.0
# 313  [{'alias': 'restaurants', 'title': 'Restaurant...             1     2.0
# 146  [{'alias': 'restaurants', 'title': 'Restaurant...             1     3.0
# 162  [{'alias': 'newamerican', 'title': 'American (...             1     3.0
# 175             [{'alias': 'pizza', 'title': 'Pizza'}]             1     5.0
# 468             [{'alias': 'pizza', 'title': 'Pizza'}]             1     5.0
# 284  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...             1     5.0
# 262             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 411  [{'alias': 'markets', 'title': 'Fruits & Veggi...             1     5.0
# 213  [{'alias': 'newamerican', 'title': 'American (...             1     5.0
# 205  [{'alias': 'restaurants', 'title': 'Restaurant...             1     5.0
# 305  [{'alias': 'foodtrucks', 'title': 'Food Trucks...             1     5.0
# 494           [{'alias': 'korean', 'title': 'Korean'}]             1     1.0
#
#     transactions                                        coordinates  \
# 507        False  {'latitude': 38.5730133056641, 'longitude': -1...
# 65         False  {'latitude': 38.6095010505836, 'longitude': -1...
# 506        False  {'latitude': 38.575439, 'longitude': -121.480671}
# 482         True  {'latitude': 38.60733833, 'longitude': -121.47...
# 451        False  {'latitude': 38.6665820275127, 'longitude': -1...
# 246        False  {'latitude': 38.6421467, 'longitude': -121.383...
# 460        False    {'latitude': 38.74887, 'longitude': -121.26598}
# 480        False  {'latitude': 38.5782404, 'longitude': -121.487...
# 267        False      {'latitude': 38.639, 'longitude': -121.27424}
# 252        False  {'latitude': 38.6098899841309, 'longitude': -1...
# 405        False  {'latitude': 38.602794, 'longitude': -121.418647}
# 50         False  {'latitude': 38.690579, 'longitude': -121.4565...
# 238        False  {'latitude': 38.6270105, 'longitude': -121.445...
# 535        False    {'latitude': 38.57936, 'longitude': -121.49357}
# 313        False  {'latitude': 38.6097235232592, 'longitude': -1...
# 146        False    {'latitude': 38.75193, 'longitude': -121.28109}
# 162         True  {'latitude': 38.7098999, 'longitude': -121.291...
# 175        False  {'latitude': 38.741153717041, 'longitude': -12...
# 468        False    {'latitude': 38.74375, 'longitude': -121.25349}
# 284        False    {'latitude': 38.66264, 'longitude': -121.27263}
# 262        False  {'latitude': 38.554607, 'longitude': -121.373375}
# 411        False    {'latitude': 38.71598, 'longitude': -121.41362}
# 213        False  {'latitude': 38.5069695, 'longitude': -121.470...
# 205        False  {'latitude': 38.5650634765625, 'longitude': -1...
# 305        False     {'latitude': 38.6451, 'longitude': -121.44154}
# 494         True  {'latitude': 38.52425, 'longitude': -121.4971651}
#
#            lat        long
# 507  38.573013 -121.490189
# 65   38.609501 -121.367493
# 506  38.575439 -121.480671
# 482  38.607338 -121.476527
# 451  38.666582 -121.388769
# 246  38.642147 -121.383989
# 460  38.748870 -121.265980
# 480  38.578240 -121.487862
# 267  38.639000 -121.274240
# 252  38.609890 -121.400833
# 405  38.602794 -121.418647
# 50   38.690579 -121.456554
# 238  38.627010 -121.445811
# 535  38.579360 -121.493570
# 313  38.609724 -121.475631
# 146  38.751930 -121.281090
# 162  38.709900 -121.291313
# 175  38.741154 -121.249260
# 468  38.743750 -121.253490
# 284  38.662640 -121.272630
# 262  38.554607 -121.373375
# 411  38.715980 -121.413620
# 213  38.506969 -121.470070
# 205  38.565063 -121.408081
# 305  38.645100 -121.441540
# 494  38.524250 -121.497165

# %%
gmaps.configure(api_key=g_key)

# %%
# Using the template add the loc
info_box_template = """
<dl>
<dt>name</dt><dd>{name}</dd>
<dt>lat</dt><dd>{lat}</dd>
<dt>long</dt><dd>{long}</dd>
</dl>
"""
yelptop = [info_box_template.format(**row) for index, row in top20.iterrows()]
locations = top20[["lat", "long"]]

# use above variables for layer
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=yelptop)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#low 20
yelptail = [info_box_template.format(**row) for index, row in tail.iterrows()]
locations = tail[["lat", "long"]]

# use above variables for layer
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=yelptail)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#rating of 5 stars with at least 50 reviews
df= df.sort_values(["rating", "review_count"], ascending= False)
rate[['long', 'lat']]= rate[['long', 'lat']].astype(float, errors= "ignore")
rate= df.loc[(df["review_count"]>= 50) & (df["rating"]==5)]
rate1= rate.head(20)
rate1
# Out:
#                          name  \
# 342           Guy's For Lunch
# 359              Wally's Cafe
# 351           Roundhouse Deli
# 334          Q1227 Restaurant
# 5    Basha Taste of Jerusalem
# 348             Fourk Kitchen
# 25     The Coconut River Park
#
#                                             categories  review_count  rating  \
# 342  [{'alias': 'salad', 'title': 'Salad'}, {'alias...           672     5.0
# 359  [{'alias': 'mediterranean', 'title': 'Mediterr...           661     5.0
# 351             [{'alias': 'delis', 'title': 'Delis'}]           434     5.0
# 334  [{'alias': 'newamerican', 'title': 'American (...           210     5.0
# 5    [{'alias': 'mediterranean', 'title': 'Mediterr...           138     5.0
# 348  [{'alias': 'tradamerican', 'title': 'American ...            79     5.0
# 25                [{'alias': 'thai', 'title': 'Thai'}]            59     5.0
#
#     transactions                                        coordinates  \
# 342         True     {'latitude': 38.77181, 'longitude': -121.3106}
# 359         True  {'latitude': 38.81001517, 'longitude': -121.28...
# 351         True     {'latitude': 38.74832, 'longitude': -121.2914}
# 334        False  {'latitude': 38.753483, 'longitude': -121.251975}
# 5           True  {'latitude': 38.5990521255, 'longitude': -121....
# 348        Theft    {'latitude': 38.85103, 'longitude': -121.28631}
# 25         False  {'latitude': 38.572999, 'longitude': -121.432858}
#
#                 lat             long
# 342        38.77181        -121.3106
# 359     38.81001517    -121.28341383
# 351        38.74832        -121.2914
# 334       38.753483      -121.251975
# 5     38.5990521255   -121.401932727
# 348        38.85103       -121.28631
# 25        38.572999      -121.432858

# %%
gmaps.configure(api_key=g_key)

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>name</dt><dd>{name}</dd>
<dt>lat</dt><dd>{lat}</dd>
<dt>long</dt><dd>{long}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
rate1[['long', 'lat']]= rate1[['long', 'lat']].astype(float, errors= "ignore")

ratetop = [info_box_template.format(**row) for index, row in rate1.iterrows()]
locations = rate1[["lat", "long"]]
# use above variables for layer[]
#markers= gmaps.marker_layer(locations, hotel_info) #info_box_template)
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=ratetop)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#ratings of 2 stars and below with at least 50 reviews
df= df.sort_values("review_count", ascending= False)
ratetail=df.head(20)
ratetail[['long', 'lat']]= ratetail[['long', 'lat']].astype(float)
ratetail= df.loc[(df["review_count"]>= 50) & (df["rating"]<= 2)]
ratetail
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                   name  \
# 189          Popeyes Louisiana Kitchen
# 477  Annabelle's Pizza & Pasta Kitchen
# 509                      El Pollo Loco
# 186                      Panda Express
# 141          Popeyes Louisiana Kitchen
# 501                         McDonald's
# 260                        Dairy Queen
# 263                            Denny's
# 401                     Domino's Pizza
# 170                                KFC
# 301                            Wendy's
# 259                          Pizza Hut
# 165                        Burger King
# 273                         McDonald's
# 466                                KFC
# 321                            Wendy's
#
#                                             categories  review_count  rating  \
# 189  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           258     2.0
# 477  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...           206     1.5
# 509  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           168     2.0
# 186  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           137     2.0
# 141  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           134     2.0
# 501  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...           130     1.5
# 260  [{'alias': 'icecream', 'title': 'Ice Cream & F...           129     2.0
# 263  [{'alias': 'diners', 'title': 'Diners'}, {'ali...           127     2.0
# 401  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...           115     2.0
# 170  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           110     1.5
# 301  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...            89     2.0
# 259  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...            84     1.5
# 165  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...            73     1.5
# 273  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...            72     2.0
# 466  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...            68     1.5
# 321  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...            63     2.0
#
#     transactions                                        coordinates  \
# 189         True  {'latitude': 38.74381323181, 'longitude': -121...
# 477         True  {'latitude': 38.5827108425455, 'longitude': -1...
# 509         True  {'latitude': 38.4610820731243, 'longitude': -1...
# 186         True  {'latitude': 38.750534, 'longitude': -121.308774}
# 141        False    {'latitude': 38.49475, 'longitude': -121.42788}
# 501         True  {'latitude': 38.556738, 'longitude': -121.539888}
# 260         True  {'latitude': 38.5961005, 'longitude': -121.385...
# 263         True  {'latitude': 38.6372734743688, 'longitude': -1...
# 401        False  {'latitude': 38.6514269166317, 'longitude': -1...
# 170         True  {'latitude': 38.7274010609913, 'longitude': -1...
# 301         True  {'latitude': 38.6788683082087, 'longitude': -1...
# 259         True    {'latitude': 38.65654, 'longitude': -121.38406}
# 165         True  {'latitude': 38.659236907959, 'longitude': -12...
# 273         True  {'latitude': 38.65991805901, 'longitude': -121...
# 466         True  {'latitude': 38.6781605949466, 'longitude': -1...
# 321         True  {'latitude': 38.613323, 'longitude': -121.382343}
#
#                    lat                long
# 189     38.74381323181        -121.2751935
# 477   38.5827108425455   -121.504095700727
# 509   38.4610820731243   -121.491896334425
# 186          38.750534         -121.308774
# 141           38.49475          -121.42788
# 501          38.556738         -121.539888
# 260         38.5961005        -121.3856283
# 263   38.6372734743688   -121.381732821465
# 401   38.6514269166317   -121.503277122974
# 170   38.7274010609913   -121.271584228712
# 301   38.6788683082087   -121.268857181423
# 259           38.65654          -121.38406
# 165    38.659236907959   -121.347984313965
# 273     38.65991805901   -121.347360312939
# 466   38.6781605949466   -121.264839936788
# 321          38.613323         -121.382343

# %%
#ratebottom[['long', 'lat']]= ratebottom[['long', 'lat']].astype(float, errors= "ignore")
ratebottom = [info_box_template.format(**row) for index, row in ratetail.iterrows()]
locations = ratetail[["lat", "long"]]

# use above variables for layer
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=ratebottom)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df['transactions'] = df['transactions'].replace(
    {"['delivery']": "True", 
     "[]": "False",
     "['pickup', 'delivery']": "True", 
     "['delivery', 'pickup']": "True", 
     "['pickup']":  "False",
     "['restaurant_reservation', 'delivery']":"True", 
     "['restaurant_reservation', 'pickup', 'delivery']":"True",
     "['restaurant_reservation']":'Theft',
     "['restaurant_reservation', 'delivery', 'pickup']": "True",
    })
df
# Out:
#                    name                                         categories  \
# 20   Ramen House Ryujin  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...
# 15        Oz Korean BBQ  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 48    Iron Horse Tavern  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 40        Tres Hermanas         [{'alias': 'mexican', 'title': 'Mexican'}]
# 350          Yard House  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# ..                  ...                                                ...
# 405       Culinary Café             [{'alias': 'cafes', 'title': 'Cafes'}]
# 480          Café Hoshi             [{'alias': 'cafes', 'title': 'Cafes'}]
# 65    Outdoor Herbivore  [{'alias': 'diyfood', 'title': 'Do-It-Yourself...
# 146       Baker Dozen 2  [{'alias': 'restaurants', 'title': 'Restaurant...
# 494          Young Dong           [{'alias': 'korean', 'title': 'Korean'}]
#
#      review_count  rating transactions  \
# 20           2881     4.5         True
# 15           2647     4.0         True
# 48           2435     4.0         True
# 40           2397     4.0         True
# 350          2071     3.5         True
# ..            ...     ...          ...
# 405             1     5.0        False
# 480             1     5.0        False
# 65              1     5.0        False
# 146             1     3.0        False
# 494             1     1.0         True
#
#                                            coordinates                lat  \
# 20       {'latitude': 38.5674, 'longitude': -121.4857}            38.5674
# 15     {'latitude': 38.56349, 'longitude': -121.33496}           38.56349
# 48   {'latitude': 38.5695762064691, 'longitude': -1...   38.5695762064691
# 40     {'latitude': 38.57369, 'longitude': -121.47456}           38.57369
# 350  {'latitude': 38.768878772817, 'longitude': -12...    38.768878772817
# ..                                                 ...                ...
# 405  {'latitude': 38.602794, 'longitude': -121.418647}          38.602794
# 480  {'latitude': 38.5782404, 'longitude': -121.487...         38.5782404
# 65   {'latitude': 38.6095010505836, 'longitude': -1...   38.6095010505836
# 146    {'latitude': 38.75193, 'longitude': -121.28109}           38.75193
# 494  {'latitude': 38.52425, 'longitude': -121.4971651}           38.52425
#
#                    long
# 20            -121.4857
# 15           -121.33496
# 48    -121.490668354958
# 40           -121.47456
# 350    -121.26806509957
# ..                  ...
# 405         -121.418647
# 480        -121.4878618
# 65    -121.367492973804
# 146          -121.28109
# 494        -121.4971651
#
# [613 rows x 8 columns]

# %%
#trans= df[df["transactions"]== "True"]
trans= df.loc[(df["transactions"]== "True") & (df["rating"]== 5) & (df["review_count"]>= 50)]
trans
# Out:
#                          name  \
# 342           Guy's For Lunch
# 359              Wally's Cafe
# 351           Roundhouse Deli
# 5    Basha Taste of Jerusalem
#
#                                             categories  review_count  rating  \
# 342  [{'alias': 'salad', 'title': 'Salad'}, {'alias...           672     5.0
# 359  [{'alias': 'mediterranean', 'title': 'Mediterr...           661     5.0
# 351             [{'alias': 'delis', 'title': 'Delis'}]           434     5.0
# 5    [{'alias': 'mediterranean', 'title': 'Mediterr...           138     5.0
#
#     transactions                                        coordinates  \
# 342         True     {'latitude': 38.77181, 'longitude': -121.3106}
# 359         True  {'latitude': 38.81001517, 'longitude': -121.28...
# 351         True     {'latitude': 38.74832, 'longitude': -121.2914}
# 5           True  {'latitude': 38.5990521255, 'longitude': -121....
#
#                 lat             long
# 342        38.77181        -121.3106
# 359     38.81001517    -121.28341383
# 351        38.74832        -121.2914
# 5     38.5990521255   -121.401932727

# %%
#delivers

trans[['long', 'lat']]= trans[['long', 'lat']].astype(float, errors= "ignore")
transactions = [info_box_template.format(**row) for index, row in trans.iterrows()]
locations = trans[["lat", "long"]]

# use above variables for layer[]
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=transactions)
fig.add_layer(markers)
fig
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# Figure(layout=FigureLayout(height='420px'))

# %%
translow= df.loc[(df["transactions"]== "True") & (df["rating"]<= 2) & (df["review_count"]>= 50)]
translow
# Out:
#                                   name  \
# 189          Popeyes Louisiana Kitchen
# 477  Annabelle's Pizza & Pasta Kitchen
# 509                      El Pollo Loco
# 186                      Panda Express
# 501                         McDonald's
# 260                        Dairy Queen
# 263                            Denny's
# 170                                KFC
# 301                            Wendy's
# 259                          Pizza Hut
# 165                        Burger King
# 273                         McDonald's
# 466                                KFC
# 321                            Wendy's
#
#                                             categories  review_count  rating  \
# 189  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           258     2.0
# 477  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...           206     1.5
# 509  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           168     2.0
# 186  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           137     2.0
# 501  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...           130     1.5
# 260  [{'alias': 'icecream', 'title': 'Ice Cream & F...           129     2.0
# 263  [{'alias': 'diners', 'title': 'Diners'}, {'ali...           127     2.0
# 170  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           110     1.5
# 301  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...            89     2.0
# 259  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...            84     1.5
# 165  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...            73     1.5
# 273  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...            72     2.0
# 466  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...            68     1.5
# 321  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...            63     2.0
#
#     transactions                                        coordinates  \
# 189         True  {'latitude': 38.74381323181, 'longitude': -121...
# 477         True  {'latitude': 38.5827108425455, 'longitude': -1...
# 509         True  {'latitude': 38.4610820731243, 'longitude': -1...
# 186         True  {'latitude': 38.750534, 'longitude': -121.308774}
# 501         True  {'latitude': 38.556738, 'longitude': -121.539888}
# 260         True  {'latitude': 38.5961005, 'longitude': -121.385...
# 263         True  {'latitude': 38.6372734743688, 'longitude': -1...
# 170         True  {'latitude': 38.7274010609913, 'longitude': -1...
# 301         True  {'latitude': 38.6788683082087, 'longitude': -1...
# 259         True    {'latitude': 38.65654, 'longitude': -121.38406}
# 165         True  {'latitude': 38.659236907959, 'longitude': -12...
# 273         True  {'latitude': 38.65991805901, 'longitude': -121...
# 466         True  {'latitude': 38.6781605949466, 'longitude': -1...
# 321         True  {'latitude': 38.613323, 'longitude': -121.382343}
#
#                    lat                long
# 189     38.74381323181        -121.2751935
# 477   38.5827108425455   -121.504095700727
# 509   38.4610820731243   -121.491896334425
# 186          38.750534         -121.308774
# 501          38.556738         -121.539888
# 260         38.5961005        -121.3856283
# 263   38.6372734743688   -121.381732821465
# 170   38.7274010609913   -121.271584228712
# 301   38.6788683082087   -121.268857181423
# 259           38.65654          -121.38406
# 165    38.659236907959   -121.347984313965
# 273     38.65991805901   -121.347360312939
# 466   38.6781605949466   -121.264839936788
# 321          38.613323         -121.382343

# %%
#delivers
translow[['long', 'lat']]= translow[['long', 'lat']].astype(float, errors= "ignore")

translowest = [info_box_template.format(**row) for index, row in translow.iterrows()]
locations = translow[["lat", "long"]]

# use above variables for layer[]
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=translowest)
fig.add_layer(markers)
fig
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# Figure(layout=FigureLayout(height='420px'))

# %%
#no delivery
nodelivr= df.loc[(df["transactions"]== "False") & (df["rating"]== 5) & (df["review_count"]>= 50)]
nodelivr
# Out:
#                        name  \
# 334        Q1227 Restaurant
# 25   The Coconut River Park
#
#                                             categories  review_count  rating  \
# 334  [{'alias': 'newamerican', 'title': 'American (...           210     5.0
# 25                [{'alias': 'thai', 'title': 'Thai'}]            59     5.0
#
#     transactions                                        coordinates  \
# 334        False  {'latitude': 38.753483, 'longitude': -121.251975}
# 25         False  {'latitude': 38.572999, 'longitude': -121.432858}
#
#             lat          long
# 334   38.753483   -121.251975
# 25    38.572999   -121.432858

# %%
nodelivr5star= df.loc[(df["transactions"]== "False") & (df["rating"]<=2) & (df["review_count"]>= 50)]
nodelivr5star
# Out:
#                           name  \
# 141  Popeyes Louisiana Kitchen
# 401             Domino's Pizza
#
#                                             categories  review_count  rating  \
# 141  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...           134     2.0
# 401  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...           115     2.0
#
#     transactions                                        coordinates  \
# 141        False    {'latitude': 38.49475, 'longitude': -121.42788}
# 401        False  {'latitude': 38.6514269166317, 'longitude': -1...
#
#                    lat                long
# 141           38.49475          -121.42788
# 401   38.6514269166317   -121.503277122974
